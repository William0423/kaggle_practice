# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()
X_train_full.shape


X_valid, X_train = X_train_full[:5000] / 255., X_train_full[5000:] / 255.
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test / 255.

X_valid.shape
X_test.shape
# Out:
# (10000, 28, 28)

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]
class_names[y_train[0]]
# Out:
# 'Coat'

# %%
# model = keras.models.Sequential()
# model.add(keras.layers.Flatten(input_shape=[28, 28]))
# model.add(keras.layers.Dense(300, activation="relu"))
# model.add(keras.layers.Dense(100, activation="relu"))
# model.add(keras.layers.Dense(10, activation="softmax"))
# model.layers
# Out:
# [<tensorflow.python.keras.layers.core.Flatten at 0x138750f50>,
#  <tensorflow.python.keras.layers.core.Dense at 0x138607090>,
#  <tensorflow.python.keras.layers.core.Dense at 0x138718e50>,
#  <tensorflow.python.keras.layers.core.Dense at 0x15a468c50>]

# %%
# model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 300)               235500
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
# keras.utils.plot_model(model, "my_fashion_mnist_model.png", show_shapes=True)
# model.compile(loss="sparse_categorical_crossentropy",
#               optimizer="sgd",
#               metrics=["accuracy"])

# %%
# history = model.fit(X_train, y_train, epochs=30,
#                     validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/30
# 1719/1719 [==============================] - 11s 6ms/step - loss: 0.7241 - accuracy: 0.7576 - val_loss: 0.5328 - val_accuracy: 0.8138
# Epoch 2/30
#  - ETA: 1s - loss: 0.4963 - accuracy: 0.8268
# Epoch 3/30
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.4451 - accuracy: 0.8428 - val_loss: 0.4181 - val_accuracy: 0.8590
# Epoch 4/30
#  - ETA: 7s - loss: 0.4213 - accuracy: 0.8515
# Epoch 5/30
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3967 - accuracy: 0.8609 - val_loss: 0.3738 - val_accuracy: 0.8746
# Epoch 6/30
# 1719/1719 [==============================] - 11s 6ms/step - loss: 0.3801 - accuracy: 0.8663 - val_loss: 0.3782 - val_accuracy: 0.8724
# Epoch 7/30
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.3656 - accuracy: 0.8707 - val_loss: 0.3711 - val_accuracy: 0.8660
# Epoch 8/30
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.3545 - accuracy: 0.8737 - val_loss: 0.3615 - val_accuracy: 0.8762
# Epoch 9/30
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.3427 - accuracy: 0.8788 - val_loss: 0.3462 - val_accuracy: 0.8798
# Epoch 10/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3333 - accuracy: 0.8815 - val_loss: 0.3509 - val_accuracy: 0.8770
# Epoch 11/30
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.3246 - accuracy: 0.8843 - val_loss: 0.3422 - val_accuracy: 0.8778
# Epoch 12/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3175 - accuracy: 0.8867 - val_loss: 0.3301 - val_accuracy: 0.8822
# Epoch 13/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3090 - accuracy: 0.8893 - val_loss: 0.3279 - val_accuracy: 0.8824
# Epoch 14/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3018 - accuracy: 0.8914 - val_loss: 0.3467 - val_accuracy: 0.8742
# Epoch 15/30
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.2955 - accuracy: 0.8942 - val_loss: 0.3405 - val_accuracy: 0.8782
# Epoch 16/30
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.2898 - accuracy: 0.8953 - val_loss: 0.3330 - val_accuracy: 0.8782
# Epoch 17/30
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.2835 - accuracy: 0.8979 - val_loss: 0.3192 - val_accuracy: 0.8870
# Epoch 18/30
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.2778 - accuracy: 0.9002 - val_loss: 0.3109 - val_accuracy: 0.8878
# Epoch 19/30
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.2722 - accuracy: 0.9019 - val_loss: 0.3078 - val_accuracy: 0.8884
# Epoch 20/30
#  - ETA: 1s - loss: 0.2683 - accuracy: 0.9037
# Epoch 21/30
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.2631 - accuracy: 0.9055 - val_loss: 0.3034 - val_accuracy: 0.8904
# Epoch 22/30
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.2579 - accuracy: 0.9078 - val_loss: 0.3033 - val_accuracy: 0.8904
# Epoch 23/30
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.2530 - accuracy: 0.9085 - val_loss: 0.3214 - val_accuracy: 0.8856
# Epoch 24/30
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.2488 - accuracy: 0.9107 - val_loss: 0.3031 - val_accuracy: 0.8908
# Epoch 25/30
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.2456 - accuracy: 0.9106 - val_loss: 0.3208 - val_accuracy: 0.8828
# Epoch 26/30
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.2408 - accuracy: 0.9136 - val_loss: 0.3151 - val_accuracy: 0.8872
# Epoch 27/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2373 - accuracy: 0.9142 - val_loss: 0.3031 - val_accuracy: 0.8896
# Epoch 28/30
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.2335 - accuracy: 0.9160 - val_loss: 0.2943 - val_accuracy: 0.8910
# Epoch 29/30
#  361/1719 [=====>........................] - ETA: 5s - loss: 0.2232 - accuracy: 0.9204

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
housing = fetch_california_housing()

X_train_full, X_test, y_train_full, y_test = train_test_split(housing.data, housing.target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
# model = tf.keras.models.Sequential([
#     tf.keras.layers.Dense(30, activation="relu", input_shape=X_train.shape[1:]),
#     tf.keras.layers.Dense(1)
# ])

model = keras.models.Sequential([
    keras.layers.Dense(30, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(1)
])

# model.compile(loss="mean_squared_error", optimizer=tf.keras.optimizers.SGD(lr=1e-3))
# history = model.fit(X_train, y_train, epochs=20, validation_data=(X_valid, y_valid))
# mse_test = model.evaluate(X_test, y_test)
# X_new = X_test[:3]
# y_pred = model.predict(X_new)


model.compile(loss="mean_squared_error", optimizer=keras.optimizers.SGD(lr=1e-3))
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_valid, y_valid))
mse_test = model.evaluate(X_test, y_test)
X_new = X_test[:3]
y_pred = model.predict(X_new)
# Out:
# Epoch 1/20
# 363/363 [==============================] - 2s 5ms/step - loss: 1.8737 - val_loss: 727538.1875
# Epoch 2/20
# 363/363 [==============================] - 2s 5ms/step - loss: 0.6360 - val_loss: 367457.0000
# Epoch 3/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.5649 - val_loss: 252966.8750
# Epoch 4/20
#  - ETA: 0s - loss: 0.5354
# Epoch 5/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.5143 - val_loss: 188302.0000
# Epoch 6/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4965 - val_loss: 173826.8125
# Epoch 7/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4821 - val_loss: 142559.3125
# Epoch 8/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4702 - val_loss: 130993.3906
# Epoch 9/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4602 - val_loss: 121874.2266
# Epoch 10/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4519 - val_loss: 105618.8594
# Epoch 11/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4452 - val_loss: 104026.3047
# Epoch 12/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4393 - val_loss: 92332.9766
# Epoch 13/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4343 - val_loss: 84339.0078
# Epoch 14/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4301 - val_loss: 77445.9062
# Epoch 15/20
# 363/363 [==============================] - 1s 4ms/step - loss: 0.4264 - val_loss: 76056.3672
# Epoch 16/20
# 363/363 [==============================] - 1s 4ms/step - loss: 0.4232 - val_loss: 71529.7812
# Epoch 17/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4206 - val_loss: 69059.1094
# Epoch 18/20
# 363/363 [==============================] - 1s 3ms/step - loss: 0.4181 - val_loss: 66850.3516
# Epoch 19/20
# 363/363 [==============================] - 1s 4ms/step - loss: 0.4159 - val_loss: 66543.6250
# Epoch 20/20
# 363/363 [==============================] - 1s 4ms/step - loss: 0.4140 - val_loss: 62248.2578
# 162/162 [==============================] - 0s 3ms/step - loss: 57232.7578

# %%
import pandas as pd
plt.plot(pd.DataFrame(history.history))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
y_pred
